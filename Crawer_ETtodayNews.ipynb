# %%
import requests
from bs4 import BeautifulSoup

# %%
url='https://www.ettoday.net/news/news-list.htm'
res = requests.get(url)
soup = BeautifulSoup(res.text)
soup
# Out:
# <!DOCTYPE html>
# <html itemscope="" itemtype="http://schema.org/WebSite" lang="zh-Hant" prefix="og:http://ogp.me/ns#" xmlns:wb="http://open.weibo.com/wb">
# <head>
# <meta charset="utf-8"/>
# <!-- ★★★以下非共用★★★ 開始 -->
# <meta content="noarchive" name="robots"/>
# <title>新聞總覽 | ETtoday新聞雲</title>
# <link href="https://www.ettoday.net/news/news-list-2020-05-21-0.htm" rel="canonical"/>
# <!-- 網頁社群分享meta 開始 -->
# <meta content="https://www.ettoday.net/news/news-list-2020-05-21-0.htm" itemprop="url" property="og:url"/>
# <meta content="新聞總覽 | ETtoday新聞雲" itemprop="name" property="og:title"/>
# <meta content="https://cdn2.ettoday.net/style/ettoday2017/images/push.jpg" itemprop="image" property="og:image"/>
# <meta content="1200" property="og:image:width"/>
# <meta content="628" property="og:image:height"/>
# <meta content="article" property="og:type"/>
# <meta content="ETtoday.net線上提供即時新聞，包括政治、財經、社會及國際要聞，以及生活、消費、寵物、新奇、娛樂、運動、旅遊資訊和相關新聞報導。" name="description"/>
# ...

# %%
a = soup.find(name ='div',attrs={"class":"part_list_2"})
a = a.select("h3")
a
# Out:
# [<h3><span class="date">2020/05/21 10:24</span><em class="tag c_local">地方</em><a href="/news/20200521/1719249.htm" target="_blank">圓滿畢生心願充實大台南沿海救護能量　市民捐贈救護車回饋社會</a></h3>,
#  <h3><span class="date">2020/05/21 10:24</span><em class="tag c_global">國際</em><a href="/news/20200521/1719142.htm" target="_blank">砲轟中國干涉內政！捷克參議院50：1壓倒性通過「支持參議院長訪台」</a></h3>,
#  <h3><span class="date">2020/05/21 10:24</span><em class="tag c_china">大陸</em><a href="/news/20200521/1719228.htm" target="_blank">刑事局長去年曾訪大陸　陳明通：兩岸「小兩會」仍持續溝通</a></h3>,
#  <h3><span class="date">2020/05/21 10:22</span><em class="tag c_finance">財經</em><a href="/news/20200521/1719246.htm" target="_blank">貿協改變行銷策略　舉辦逾百場線上拓銷團成功取得商機</a></h3>,
#  <h3><span class="date">2020/05/21 10:22</span><em class="tag c_sport">體育</em><a href="/news/20200521/1719241.htm" target="_blank">NBA主席預計6月宣布復賽！開打時間曝光　奧蘭多迪士尼成優先選擇</a></h3>,
# ...

# %%
for item in a:
    newstime = item.select('span')[0].text
    newsTag = item.select('em')[0].text
    newsTitle = item.select('a')[0].text
    newsurl = 'https://www.ettoday.net/'+item.select('a')[0]['href']
    print("%s %s %s %s" %(newstime,newsTag,newsTitle,newsurl))
# Out:
# 2020/05/21 10:24 地方 圓滿畢生心願充實大台南沿海救護能量　市民捐贈救護車回饋社會 https://www.ettoday.net//news/20200521/1719249.htm
